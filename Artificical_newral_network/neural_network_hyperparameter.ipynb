# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input,Dropout, BatchNormalization, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import normalize
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier

# %%
# ! pip install scikeras

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
X_train = normalize(X_train)
X_test = normalize(X_test)

# %%
X_train.shape, y_train.shape, X_test.shape,y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
model = Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(32,activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate = 0.01), metrics=['accuracy'],loss='sparse_categorical_crossentropy')

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8816 - loss: 0.3831
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9526 - loss: 0.1554
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9619 - loss: 0.1246
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9657 - loss: 0.1132
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9673 - loss: 0.1047
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9705 - loss: 0.0982
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9726 - loss: 0.0899
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9732 - loss: 0.0854
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9747 - loss: 0.0807
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9758 - loss: 0.0823

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9562 - loss: 0.2107
# [0.19157829880714417, 0.9616000056266785]

# %%
def built_model(n_hidden = 1, n_neuron = 32, learning_rate = 0.001, kerenl_initializer = 'he_normal',add_dropout = False,add_batch_normalization = False):
    model = Sequential()
    model.add(Input(shape=(28,28)))
    model.add(Flatten())
    for layer in range(n_hidden):
        model.add(Dense(n_neuron,activation='relu',kernel_initializer=kerenl_initializer))
        if add_dropout:
            model.addd(Dropout(0.2))
        if add_batch_normalization:
            model.add(BatchNormalization())
    model.add(Dense(10,activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=learning_rate),loss='sparse_categorical_crossentropy',metrics = ['accuracy'])

    return model

# %%
keras_clf = KerasClassifier(built_model)
keras_clf.fit(X_train,y_train,epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.7962 - loss: 0.7152
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9293 - loss: 0.2392
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9453 - loss: 0.1895
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9535 - loss: 0.1608
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9583 - loss: 0.1419
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9645 - loss: 0.1235
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9681 - loss: 0.1097
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9694 - loss: 0.1054
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9731 - loss: 0.0939
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9745 - loss: 0.0872
# KerasClassifier(
# 	model=<function built_model at 0x0000023FB17AB380>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# )

# %%
keras_clf.score(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 0.9645

# %%
param_grid = {
    'model__n_hidden': [3,4],
    'model__n_neuron' : [64,128,256],
    # 'model__n_learning_rate':[0.001,0.003,0.005],
    # 'model__n_dropout':[True,False],
    # 'model__n_add_batch_norm':[True,False]

}

# %%
keras_clf = KerasClassifier(built_model)

# %%
grid_search = GridSearchCV(keras_clf,param_grid=param_grid,cv= 2,verbose=2,)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7995 - loss: 0.6853
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [CV] END ..............model__n_hidden=3, model__n_neuron=64; total time=  15.0s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7735 - loss: 0.7465
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [CV] END ..............model__n_hidden=3, model__n_neuron=64; total time=  10.4s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8187 - loss: 0.5824
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=3, model__n_neuron=128; total time=  11.6s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8241 - loss: 0.5855
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=3, model__n_neuron=128; total time=  12.2s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8513 - loss: 0.4799
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=3, model__n_neuron=256; total time=  14.2s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8527 - loss: 0.4803
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [CV] END .............model__n_hidden=3, model__n_neuron=256; total time=  16.3s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7741 - loss: 0.6830
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [CV] END ..............model__n_hidden=4, model__n_neuron=64; total time=  10.9s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7813 - loss: 0.6955
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [CV] END ..............model__n_hidden=4, model__n_neuron=64; total time=  10.8s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8157 - loss: 0.5728
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=4, model__n_neuron=128; total time=  12.1s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8246 - loss: 0.5624
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=4, model__n_neuron=128; total time=  13.0s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8468 - loss: 0.4906
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# [CV] END .............model__n_hidden=4, model__n_neuron=256; total time=  16.0s
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8494 - loss: 0.4803
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# [CV] END .............model__n_hidden=4, model__n_neuron=256; total time=  17.1s
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.8893 - loss: 0.3613
# GridSearchCV(cv=2,
#              estimator=KerasClassifier(model=<function built_model at 0x0000023FB17AB380>),
#              param_grid={'model__n_hidden': [3, 4],
#                          'model__n_neuron': [64, 128, 256]},
#              verbose=2)

# %%
grid_search.score(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 0.9657

# %%
grid_search.best_params_
# Out:
# {'model__n_hidden': 3, 'model__n_neuron': 256}

# %%
grid_search.best_estimator_
# Out:
# KerasClassifier(
# 	model=<function built_model at 0x0000023FB17AB380>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# 	model__n_hidden=3
# 	model__n_neuron=256
# )

# %% [markdown]
# ### Here we can see the from Grid search cv the score has been incresased a bit
